# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sys
import re

# %%
fname = "/content/drive/My Drive/Task 2/Data/baby1990.html"

# %% [markdown]
# Defining Function and creating summary as per problem statement

# %%
def extract_web(fname):
    html_file = open(fname, 'r')
    source_data = html_file.read()
    names = []
    year = re.findall(r'Popularity\sin\s(\d\d\d\d)', source_data)
    content = re.findall(r'<td>(\d+)</td><td>(\w+)</td>\<td>(\w+)</td>', source_data)
    names_to_rank =  {}
    for rank_tuple in content:
      (rank, boyname, girlname) = rank_tuple  # unpack the tuple into 3 vars
      if boyname not in names_to_rank:
        names_to_rank[boyname] = rank
      if girlname not in names_to_rank:
        names_to_rank[girlname] = rank
    sorted_names = sorted(names_to_rank.keys())
    for name in sorted_names:
      names.append(name + " " + names_to_rank[name])
    
    return names
  
summary1 = extract_web(fname)

# %%
summary1
# Out:
# ['Aaron 34',
#  'Abbey 482',
#  'Abbie 685',
#  'Abby 222',
#  'Abdul 934',
#  'Abel 384',
#  'Abigail 90',
#  'Abraham 246',
#  'Abram 920',
#  'Adam 32',
#  'Adan 548',
#  'Addison 645',
#  'Adolfo 649',
#  'Adrian 94',
#  'Adriana 144',
#  'Adrianna 325',
#  'Adrianne 783',
#  'Adrienne 233',
#  'Agustin 627',
#  'Ahmad 562',
#  'Ahmed 721',
#  'Aidan 889',
#  'Aileen 851',
#  'Aimee 272',
#  'Aisha 568',
#  'Aja 940',
#  'Akeem 405',
#  'Alaina 441',
#  'Alan 125',
#  'Alana 368',
#  'Alanna 474',
#  'Alannah 936',
#  'Albert 167',
#  'Alberto 225',
#  'Alden 949',
#  'Aldo 792',
#  'Alec 271',
#  'Alecia 678',
#  'Alejandra 211',
#  'Alejandro 126',
#  'Alesha 695',
#  'Alessandra 829',
#  'Alex 59',
#  'Alexa 146',
#  'Alexander 28',
#  'Alexandra 37',
#  'Alexandre 950',
#  'Alexandrea 653',
#  'Alexandria 95',
#  'Alexandro 837',
#  'Alexia 557',
#  'Alexis 66',
#  'Alfonso 423',
#  'Alfred 364',
#  'Alfredo 272',
#  'Ali 474',
#  'Alice 347',
#  'Alicia 53',
#  'Alina 664',
# ...

# %%
summary2 = extract_web('/content/drive/My Drive/Task 2/Data/baby1992.html')
summary3 = extract_web('/content/drive/My Drive/Task 2/Data/baby1994.html')
summary4 = extract_web('/content/drive/My Drive/Task 2/Data/baby1996.html')
summary5 = extract_web('/content/drive/My Drive/Task 2/Data/baby1998.html')
summary6 = extract_web('/content/drive/My Drive/Task 2/Data/baby2000.html')
summary7 = extract_web('/content/drive/My Drive/Task 2/Data/baby2002.html')
summary8 = extract_web('/content/drive/My Drive/Task 2/Data/baby2004.html')
summary9 = extract_web('/content/drive/My Drive/Task 2/Data/baby2006.html')
summary10 = extract_web('/content/drive/My Drive/Task 2/Data/baby2008.html')

# %%
summary10
# Out:
# ['Aaden 343',
#  'Aaliyah 77',
#  'Aarav 921',
#  'Aaron 50',
#  'Abagail 874',
#  'Abbey 822',
#  'Abbie 737',
#  'Abbigail 508',
#  'Abby 259',
#  'Abdiel 984',
#  'Abdullah 953',
#  'Abel 360',
#  'Abigail 8',
#  'Abigayle 936',
#  'Abraham 187',
#  'Abram 548',
#  'Abril 522',
#  'Ace 714',
#  'Ada 598',
#  'Adalyn 526',
#  'Adalynn 845',
#  'Adam 72',
#  'Adan 299',
#  'Addison 12',
#  'Addisyn 556',
#  'Addyson 240',
#  'Adelaide 551',
#  'Adeline 361',
#  'Adelyn 577',
#  'Aden 254',
#  'Adison 900',
#  'Aditya 702',
#  'Adolfo 731',
#  'Adonis 854',
#  'Adrian 56',
#  'Adriana 124',
#  'Adrianna 173',
#  'Adriel 584',
#  'Adrien 727',
#  'Adrienne 786',
#  'Adyson 648',
#  'Aedan 821',
#  'Agustin 740',
#  'Ahmad 559',
#  'Ahmed 576',
#  'Aidan 59',
#  'Aiden 16',
#  'Aidyn 699',
#  'Aileen 483',
#  'Aimee 779',
#  'Ainsley 441',
#  'Aisha 764',
#  'Aiyana 595',
#  'Akira 705',
#  'Alaina 223',
#  'Alan 135',
#  'Alana 166',
#  'Alani 913',
#  'Alanna 461',
#  'Alannah 938',
# ...

# %%
def extract_df(fname):
    html_file = open(fname, 'r')
    source_data = html_file.read()
    names = []
    year = re.findall(r'Popularity\sin\s(\d\d\d\d)', source_data)
    content = re.findall(r'<td>(\d+)</td><td>(\w+)</td>\<td>(\w+)</td>', source_data)
    df1 = pd.DataFrame(year,columns=['Year'])
    df2 = pd.DataFrame(content,columns =['Rank', 'MaleName','FemaleName'])
    df3 = pd.concat([df1, df2], axis=1)
    df3 = df3.fillna(method='ffill')

    return df3

data1 = extract_df(fname)

# %%
data1.head()
# Out:
#    Year Rank     MaleName FemaleName
# 0  1990    1      Michael    Jessica
# 1  1990    2  Christopher     Ashley
# 2  1990    3      Matthew   Brittany
# 3  1990    4       Joshua     Amanda
# 4  1990    5       Daniel   Samantha

# %%
data2 = extract_df('/content/drive/My Drive/Task 2/Data/baby1992.html')
data3 = extract_df('/content/drive/My Drive/Task 2/Data/baby1994.html')
data4 = extract_df('/content/drive/My Drive/Task 2/Data/baby1996.html')
data5 = extract_df('/content/drive/My Drive/Task 2/Data/baby1998.html')
data6 = extract_df('/content/drive/My Drive/Task 2/Data/baby2000.html')
data7 = extract_df('/content/drive/My Drive/Task 2/Data/baby2002.html')
data8 = extract_df('/content/drive/My Drive/Task 2/Data/baby2004.html')
data9 = extract_df('/content/drive/My Drive/Task 2/Data/baby2006.html')
data10 = extract_df('/content/drive/My Drive/Task 2/Data/baby2008.html')

# %%
data10.tail()
# Out:
#      Year  Rank MaleName FemaleName
# 995  2008   996   Kolten   Carleigh
# 996  2008   997   Damari      Iyana
# 997  2008   998     Hugh     Kenley
# 998  2008   999   Jensen     Sloane
# 999  2008  1000    Yurem    Elianna
